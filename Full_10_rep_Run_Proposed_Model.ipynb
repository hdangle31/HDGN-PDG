# %%
# !cp /content/drive/MyDrive/HGDC/dataset_STRINGdb_ten_5CV.pkl /content
# !cp /content/drive/MyDrive/HGDC/dataset_CPDB_ten_5CV.pkl /content
# !cp /content/drive/MyDrive/HGDC/dataset_IREF_ten_5CV.pkl /content
# !cp /content/drive/MyDrive/HGDC/dataset_IREF_2015_ten_5CV.pkl /content
# !cp /content/drive/MyDrive/HGDC/dataset_PCNET_ten_5CV.pkl /content
# !cp /content/drive/MyDrive/HGDC/dataset_MULTINET_ten_5CV.pkl /content



# !pip install torch_geometric
import torch

# !pip uninstall torch-scatter torch-sparse torch-geometric torch-cluster  --y
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.6 MB/s eta 0:00:00
# ...
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# Found existing installation: torch-geometric 2.7.0
# Uninstalling torch-geometric-2.7.0:
#   Successfully uninstalled torch-geometric-2.7.0
# WARNING: Skipping torch-cluster as it is not installed.
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 198.6 MB/s eta 0:00:00
# ...
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.3 MB/s eta 0:00:00
# ...
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 57.9 MB/s eta 0:00:00
# ...

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 19.0 MB/s eta 0:00:00
# ...

# %%
# !cp /content/drive/MyDrive/HGDC/proposed_model_7.py /content
# !cp /content/drive/MyDrive/HGDC/tune_acm_emogi.py /content
# !cp /content/drive/MyDrive/HGDC/dataset_IREF_ten_5CV_newseed_finetune.pkl /content
# !cp /content/drive/MyDrive/HGDC/proposed_model_7_new.py /content
# !cp /content/drive/MyDrive/HGDC/proposed_model_7_new_seedfix.py /content

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_PCNET_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 19781
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 5449448
#   Labelled    : 6342
#   Cancer genes: 859  (13.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
#   Computing k-core decomposition...
#   Static topo shape: (19781, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=5073 val=1269 | fold 1/50 → AUPRC=0.7475  AUROC=0.9157  α=[LP:0.32 HP:0.27 ID:0.41]  gate=0.4514
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_STRINGdb_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 13179
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 673096
#   Labelled    : 3198
#   Cancer genes: 783  (24.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
#   Computing k-core decomposition...
#   Static topo shape: (13179, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2558 val= 640 | fold 1/50 → AUPRC=0.7808  AUROC=0.8867  α=[LP:0.32 HP:0.27 ID:0.41]  gate=0.4615
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_IREF_2015_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 12129
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 183618
#   Labelled    : 2758
#   Cancer genes: 785  (28.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
#   Computing k-core decomposition...
#   Static topo shape: (12129, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2206 val= 552 | fold 1/50 → AUPRC=0.8082  AUROC=0.9173  α=[LP:0.31 HP:0.27 ID:0.41]  gate=0.4487
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_MULTINET_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 14398
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 219134
#   Labelled    : 4499
#   Cancer genes: 790  (17.6% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
#   Computing k-core decomposition...
#   Static topo shape: (14398, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=3599 val= 900 | fold 1/50 → AUPRC=0.8165  AUROC=0.9392  α=[LP:0.31 HP:0.30 ID:0.38]  gate=0.5194
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_CPDB_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 13627
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 504378
#   Labelled    : 2983
#   Cancer genes: 796  (26.7% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
#   Computing k-core decomposition...
#   Static topo shape: (13627, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2386 val= 597 | fold 1/50 → AUPRC=0.8115  AUROC=0.8841  α=[LP:0.32 HP:0.27 ID:0.41]  gate=0.4651
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 31 --data "dataset_IREF_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 31
#
# Loading data...
#   Nodes       : 17013
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 738722
#   Labelled    : 4892
#   Cancer genes: 836  (17.1% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
# /content/proposed_model_7_new_seedfix.py:613: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 10 --data "dataset_IREF_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 10
#
# Loading data...
#   Nodes       : 17013
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 738722
#   Labelled    : 4892
#   Cancer genes: 836  (17.1% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
# /content/proposed_model_7_new_seedfix.py:613: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# ...

# %%
# !python proposed_model_7_new_seedfix.py --seed 10 --data "dataset_IREF_ten_5CV.pkl" --reps 10 --omics_dim 48 --hidden_dim 144 --n_layers 2 --temperature 2.0 --dropout 0.5 --weight_decay 0.0002421641899359393 --lr 0.0037975573394087546 --epochs 200 --patience 30
# Out:
# Using device: cuda  |  seed: 10
#
# Loading data...
#   Nodes       : 17013
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 738722
#   Labelled    : 4892
#   Cancer genes: 836  (17.1% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (std_nbr_deg, log1p(2hop_sum), log1p(pr*N), clust_coeff, mean_nbr_deg, kcore, 2hop_unique)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (std_nbr_deg, log1p(2hop_sum), log1p(pr*N),
#    clust_coeff, mean_nbr_deg, kcore, 2hop_unique)...
# /content/proposed_model_7_new_seedfix.py:613: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# ...

# %%
  BEST_CONFIG = {
    "omics_dim": 48,
    "hidden_dim": 144,
    "n_layers": 2,
    "temperature": 2.0,
    "dropout": 0.5,
    "weight_decay": 0.0002421641899359393,
    "lr": 0.0037975573394087546,
    "epochs": 200,
    "patience": 30
}

# %%
# !python proposed_model_7.py --data "dataset_STRINGdb_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 13179
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 673096
#   Labelled    : 3198
#   Cancer genes: 783  (24.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (13179, 7)  (expected [N, 7])
# ...

# %%
# !python proposed_model_7.py --data "dataset_IREF_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 17013
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 738722
#   Labelled    : 4892
#   Cancer genes: 836  (17.1% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 48, 'hidden_dim': 144, 'n_layers': 2, 'dropout': 0.5, 'temperature': 2.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.0037975573394087546, 'weight_decay': 0.0002421641899359393, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
# /content/proposed_model_7.py:559: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# ...

# %%
# Quick run (40 trials, ~200 folds total)
# !python tune_acm_emogi.py --data "dataset_IREF_ten_5CV_newseed_finetune.pkl" --n-trials 40
# Out:
# Device          : cuda
# Trials planned  : 40
# CV reps/trial   : 1  (5 folds/trial)
#
# Loading data from dataset_IREF_ten_5CV_newseed_finetune.pkl ...
# Precomputing LP-normalised adjacency ...
# Precomputing static topology features
#   (std/mean nbr-deg, log1p-2hop-sum, log1p-PR,
#    clustering coeff, k-core, 2-hop unique) ...
# /content/proposed_model_7.py:559: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# /content/proposed_model_7.py:562: RuntimeWarning: invalid value encountered in divide
#   nbr_deg_sq / deg - (nbr_deg_sum / deg) ** 2,
#   Computing k-core decomposition...
#   Topo feature matrix: (17013, 7)  (expected [N, 7])
#
# /content/tune_acm_emogi.py:349: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler = TPESampler(seed=args.seed, multivariate=True)
# ...

# %%
# Quick run (40 trials, ~200 folds total)
# !python tune_acm_emogi.py --data "dataset_IREF_ten_5CV.pkl" --n-trials 40
# Out:
# Device          : cuda
# Trials planned  : 40
# CV reps/trial   : 1  (5 folds/trial)
#
# Loading data from dataset_IREF_ten_5CV.pkl ...
# Precomputing LP-normalised adjacency ...
# Precomputing static topology features
#   (std/mean nbr-deg, log1p-2hop-sum, log1p-PR,
#    clustering coeff, k-core, 2-hop unique) ...
# /content/proposed_model_7.py:559: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# /content/proposed_model_7.py:562: RuntimeWarning: invalid value encountered in divide
#   nbr_deg_sq / deg - (nbr_deg_sum / deg) ** 2,
#   Computing k-core decomposition...
#   Topo feature matrix: (17013, 7)  (expected [N, 7])
#
# /content/tune_acm_emogi.py:349: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler = TPESampler(seed=args.seed, multivariate=True)
# ...

# %%
# !python tune_acm_emogi.py --data "dataset_STRINGdb_ten_5CV.pkl" --n-trials 40
# Out:
# Device          : cuda
# Trials planned  : 40
# CV reps/trial   : 1  (5 folds/trial)
#
# Loading data from dataset_STRINGdb_ten_5CV.pkl ...
# Precomputing LP-normalised adjacency ...
# Precomputing static topology features
#   (std/mean nbr-deg, log1p-2hop-sum, log1p-PR,
#    clustering coeff, k-core, 2-hop unique) ...
#   Computing k-core decomposition...
#   Topo feature matrix: (13179, 7)  (expected [N, 7])
#
# /content/tune_acm_emogi.py:349: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler = TPESampler(seed=args.seed, multivariate=True)
# [I 2026-05-15 18:05:15,825] A new study created in memory with name: acm_emogi_v7
# Running 40 trials (n_jobs=1, sampler=TPE, pruner=Median) ...
#
#   0% 0/40 [00:00<?, ?it/s]  Trial   0  AUPRC=0.7943  params={'omics_dim': 48, 'hd_mult': 2, 'n_layers': 3, 'temperature': 4.0, 'dropout': 0.5, 'weight_decay': 1.0994335574766187e-05, 'lr': 0.004665303012212832}
# ...

# %%
  BEST_CONFIG = {
    "omics_dim": 48,
    "hidden_dim": 192,
    "n_layers": 1,
    "temperature": 3.5,
    "dropout": 0.6,
    "weight_decay": 2.5946042500837737e-05,
    "lr": 0.004615130874832513,
    "epochs": 200,
    "patience": 30
}

# %%
# !python proposed_model_7.py --data "dataset_IREF_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 17013
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 738722
#   Labelled    : 4892
#   Cancer genes: 836  (17.1% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 48, 'hidden_dim': 192, 'n_layers': 1, 'dropout': 0.6, 'temperature': 3.5, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.004615130874832513, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
# /content/proposed_model_7.py:559: RuntimeWarning: invalid value encountered in divide
#   mean_nbr_deg = np.where(deg > 0, nbr_deg_sum / deg, 0.0).astype(np.float32)
# ...

# %%
# !python proposed_model_7.py --data "dataset_MULTINET_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 14398
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 219134
#   Labelled    : 4499
#   Cancer genes: 790  (17.6% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 64, 'hidden_dim': 128, 'n_layers': 2, 'dropout': 0.4, 'temperature': 3.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.001, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (14398, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=3599 val= 900 | fold 1/50 → AUPRC=0.7829  AUROC=0.9364  α=[LP:0.38 HP:0.33 ID:0.29]  gate=0.4586
# ...

# %%
# !python proposed_model_7.py --data "dataset_PCNET_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 19781
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 5449448
#   Labelled    : 6342
#   Cancer genes: 859  (13.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 64, 'hidden_dim': 128, 'n_layers': 2, 'dropout': 0.4, 'temperature': 3.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.001, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (19781, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=5073 val=1269 | fold 1/50 → AUPRC=0.7484  AUROC=0.9210  α=[LP:0.34 HP:0.37 ID:0.29]  gate=0.3965
# ...

# %%
# !python proposed_model_7.py --data "dataset_STRINGdb_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 13179
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 673096
#   Labelled    : 3198
#   Cancer genes: 783  (24.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 64, 'hidden_dim': 128, 'n_layers': 2, 'dropout': 0.4, 'temperature': 3.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.001, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (13179, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2558 val= 640 | fold 1/50 → AUPRC=0.7762  AUROC=0.8909  α=[LP:0.30 HP:0.26 ID:0.44]  gate=0.4398
# ...

# %%
# !python proposed_model_7.py --data "dataset_CPDB_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 13627
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 504378
#   Labelled    : 2983
#   Cancer genes: 796  (26.7% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 64, 'hidden_dim': 128, 'n_layers': 2, 'dropout': 0.4, 'temperature': 3.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.001, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (13627, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2386 val= 597 | fold 1/50 → AUPRC=0.8122  AUROC=0.8884  α=[LP:0.55 HP:0.26 ID:0.19]  gate=0.4639
# ...

# %%
# !python proposed_model_7.py --data "dataset_IREF_2015_ten_5CV.pkl" --reps 10
# Out:
# Using device: cuda
#
# Loading data...
#   Nodes       : 12129
#   Features    : 64  (4 omics × 16 cancer types)
#   Edges       : 183618
#   Labelled    : 2758
#   Cancer genes: 785  (28.5% of labelled)
#   Reps × Folds: 10 × 5
#
# Topology features: 7  (enriched 2-hop family: std/max nbr deg, 2-hop unique, ego density)
#
# Config: {'omics_dim': 64, 'hidden_dim': 128, 'n_layers': 2, 'dropout': 0.4, 'temperature': 3.0, 'alpha_T_init': 0.5, 'alpha_lr_mult': 1.0, 'lr': 0.001, 'weight_decay': 0.0005, 'epochs': 200, 'patience': 30}
#
# Starting 10 × 5-fold cross-validation...
#
#   Computing static topology features
#   (degree, std/mean/max nbr degree, log1p(2hop_sum),
#    PageRank, clustering coeff, k-core,
#    2-hop unique count, ego-network edge density)...
#   Computing k-core decomposition...
#   Static topo shape: (12129, 7)  (expected [N, 7])
#   Rep  0 | Fold 0 | train=2206 val= 552 | fold 1/50 → AUPRC=0.8014  AUROC=0.9177  α=[LP:0.41 HP:0.32 ID:0.27]  gate=0.4572
# ...
